# %% [markdown]
# # Demo4: kmean進一步解析

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.1-py3-none-any.whl (288 kB)
#      -------------------------------------- 288.2/288.2 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\x270\anaconda3\envs\py37tf_tmp\lib\site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: typing_extensions in c:\users\x270\anaconda3\envs\py37tf_tmp\lib\site-packages (from seaborn) (4.4.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\x270\anaconda3\envs\py37tf_tmp\lib\site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: numpy>=1.17 in c:\users\x270\anaconda3\envs\py37tf_tmp\lib\site-packages (from seaborn) (1.21.6)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\x270\anaconda3\envs\py37tf_tmp\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\x270\anaconda3\envs\py37tf_tmp\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\x270\anaconda3\envs\py37tf_tmp\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\x270\anaconda3\envs\py37tf_tmp\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\x270\anaconda3\envs\py37tf_tmp\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\x270\anaconda3\envs\py37tf_tmp\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\x270\anaconda3\envs\py37tf_tmp\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\x270\anaconda3\envs\py37tf_tmp\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\x270\anaconda3\envs\py37tf_tmp\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.1

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_blobs #產生高斯分布資料的套件: https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html#sklearn.datasets.make_blobs

X, y_true = make_blobs(n_samples=300, 
    centers=4,cluster_std=0.60, random_state=0)
plt.scatter(X[:,0], X[:, 1], s=50)

# %%
# 美化用
import seaborn as sns; sns.set()

# %%
plt.scatter(X[:,0], X[:, 1], s=50)

# %%
# 回憶一下
X_test = [[1, 10],
          [2, 20],
          [3, 30]]
X_test = np.array(X_test)
X_test
# Out:
# array([[ 1, 10],
#        [ 2, 20],
#        [ 3, 30]])

# %%
print('X_test[:,0] = ', X_test[:,0])
print('X_test[:,1] = ', X_test[:,1])
# Out:
# X_test[:,0] =  [1 2 3]
# X_test[:,1] =  [10 20 30]

# %%
from sklearn.cluster import KMeans

#kmeans = KMeans(n_clusters=4, init='k-means++')
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)

y_kmeans = kmeans.predict(X)

plt.scatter(X[:,0], X[:,1], c=y_kmeans, s=50, 
    cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], 
    c='black', s=200, alpha=0.5)

# %%
from sklearn.cluster import KMeans

#kmeans = KMeans(n_clusters=4, init='k-means++')
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)

y_kmeans = kmeans.predict(X)

plt.scatter(X[:,0], X[:,1], c=y_kmeans, s=50, 
    cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], 
    c='black', s=200, alpha=0.5)

# %%
kmeans.cluster_centers_
# Out:
# array([[-1.33465447,  7.69442683],
#        [ 0.45233231,  2.68105561]])

# %% [markdown]
# ### 畫Elbow plot檢驗k值

# %%
wcss = []
for k in range(1,8):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,8), wcss, linewidth = 2)
plt.xlabel='K'
plt.ylabel='WCSS'

# %% [markdown]
# ### 分四群

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4, init='k-means++')
#kmeans = KMeans(n_clusters=4)
kmeans.fit(X)

y_kmeans = kmeans.predict(X)

plt.scatter(X[:,0], X[:,1], c=y_kmeans, s=50, 
    cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], 
    c='black', s=200, alpha=0.5)
